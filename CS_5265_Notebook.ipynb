# %% [markdown]
# <a href="https://colab.research.google.com/github/shanfty/CS_5265_ML_Project/blob/main/CS_5265_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook for ML

# %% [markdown]
# Describe my project in a text cell including the following sections:
#
# *   Background
#     x
# *   Project Description
#     x
# *   Peroformance Metric
#     x
